# %%
#Dependencies
import plotly.plotly as py
py.sign_in('BrendanM32185', 'Hyrp0VW2bVMjzHvJt1gR')
import plotly.graph_objs as go
import pandas as pd
import numpy as np

# %%
#File to load
bull_data = "Bull_data.csv"

#Read file as df
bull_data = pd.read_csv(bull_data)

#Display table
bull_data.head()
# Out:
#   Registration Number   Animal Name  Birth Date   Sex  BW EPD  WW EPD  YW EPD  \
# 0              989376  MR. V8 421/8       43198  Bull     1.9    29.1    50.0
# 1              989377  MR. V8 424/8       43200  Bull     0.1    41.6    59.7
# 2              989378  MR. V8 439/8       43211  Bull     0.8    27.6    41.5
# 3              989379  MR. V8 448/8       43217  Bull     1.0     6.8    16.4
# 4              989380  MR. V8 456/8       43228  Bull     2.5    39.0    59.6
#
#    MAT EPD  SC EPD  Carcass Weight  ...    MARB EPD  FAT EPD  TEND EPD  \
# 0      3.8   -0.02              32  ...       -7.47     0.00     -0.07
# 1      9.1   -0.64              33  ...       -4.42     0.02     -0.15
# 2      6.4   -0.13              34  ...       -1.99     0.04      0.05
# 3      8.9    0.34               7  ...       -8.46    -0.01     -0.16
# 4      4.7   -0.59              49  ...        7.11     0.03      0.05
#
#    Doc EPD  CED EPD  CEM EPD  FS EPD   ADG EPD   DOC REV  Index
# ...

# %%
#Things to figure out

    # code a loop so that it takes the variables that are needed and inputs them the radar chart
    # (maybe go look at pyber homework and past activities)

# %%
#Radar chart plotting

data = [
    go.Scatterpolar(
      r = [39, 28, 8, 7, 28, 39, 25, 17, 45, 32, 27],
      theta = ['BW EPD','WW EPD','MAT EPD', 'SCEPD', 'CARCASS W', 'REA EPD', 
           'FAT EPD', 'TEND EPD', 'Doc EOPD', 'CEM EPD', 'FS EPD', 'BW EPD'],
      fill = 'toself',
      name = 'MR. V8 421/8'
    ),
]
layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 100]
    )
  ),
  showlegend = True
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~BrendanM32185/48.embed" height="525px" width="100%"></iframe>

# %%
#Comparison chart for two different bulls
#This, I hope, will demonstrate the trait differnece in two different animals to optimize breeding practices
data = [
    go.Scatterpolar(
      r = [39, 28, 8, 7, 28, 39, 25, 17, 45, 32, 27],
      theta = ['BW EPD','WW EPD','MAT EPD', 'SCEPD', 'CARCASS W', 'REA EPD', 
           'FAT EPD', 'TEND EPD', 'Doc EOPD', 'CEM EPD', 'FS EPD', 'BW EPD'],
      fill = 'tonext',
      name = 'MR. V8 421/8'
    ),
    go.Scatterpolar(
      r = [1.5, 10, 39, 31, 15, 1.5, 25, 42, 27, 30, 77],
      theta = ['BW EPD','WW EPD','MAT EPD', 'SCEPD', 'CARCASS W', 'REA EPD', 
           'FAT EPD', 'TEND EPD', 'Doc EOPD', 'CEM EPD', 'FS EPD', 'BW EPD'],
      fill = 'toself',
      name = 'MR. V8 424/8'
    ),
]
layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 100]
    )
  ),
  showlegend = True
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~BrendanM32185/50.embed" height="525px" width="100%"></iframe>
